# %% [markdown]
# # <font color = 'blue'> 1. Manipulating files and directories

# %% [markdown]
# 1.    `pwd`:  where am I?
# 2.   `ls` : identify files and directories
# 3.  `mv`: move file to another directory
# 4.  `cd..` move up a directory
# 5. `cp`: copy files
# 6. `cd directory`: move to another directory
# 7. 'mv file1 file2`: rename a file
# 8. `rm`: delete file
# 9. `rmdir directory`: delete directory
# 10. `mkdir path/directory`: make directory

# %% [markdown]
# # <font color = 'blue'> 2. Manipulating Data
# <font color = 'black'>
# 1. `cat filename`:  view a files contents
# 2. `less filename`:

# %%
curl 'https://raw.githubusercontent.com/raynamharris/DataForUnixCourse/master/data/chicken.fastq' -o
# Out:
#   File "<ipython-input-52-65ea7d5388ca>", line 1
#     curl https://raw.githubusercontent.com/raynamharris/DataForUnixCourse/master/data/chicken.fastq
#              ^
# SyntaxError: invalid syntax

# %%
# %less mnist_test.csv

# %%
rmdir /content/sample_Jun/

# %%
pwd
# Out:
# '/content'

# %%
cp mnist_test.csv /content/sample_data/

# %%
pwd
# Out:
# '/content'

# %%
cd sample_data/
# Out:
# /content/sample_data

# %%
# %ls
# Out:
# anscombe.json*                mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md*
